# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
wc_data = pd.read_csv('WorldCups_preview.csv')

# %%
wc_data
# Out:
#     Year       Country      Winner      Runners-Up        Third  \
# 0   1930       Uruguay     Uruguay       Argentina          USA
# 1   1934         Italy       Italy  Czechoslovakia      Germany
# 2   1938        France       Italy         Hungary       Brazil
# 3   1950        Brazil     Uruguay          Brazil       Sweden
# 4   1954   Switzerland  Germany FR         Hungary      Austria
# 5   1958        Sweden      Brazil          Sweden       France
# 6   1962         Chile      Brazil  Czechoslovakia        Chile
# 7   1966       England     England      Germany FR     Portugal
# 8   1970        Mexico      Brazil           Italy   Germany FR
# 9   1974       Germany  Germany FR     Netherlands       Poland
# 10  1978     Argentina   Argentina     Netherlands       Brazil
# 11  1982         Spain       Italy      Germany FR       Poland
# 12  1986        Mexico   Argentina      Germany FR       France
# 13  1990         Italy  Germany FR       Argentina        Italy
# ...

# %% [markdown]
# ## Count the most winning team

# %%
wc_data["Winner"].value_counts()
# Out:
# Brazil        5
# Italy         4
# Germany FR    3
# Uruguay       2
# Argentina     2
# England       1
# France        1
# Spain         1
# Germany       1
# Name: Winner, dtype: int64

# %%
wc_data["Runners-Up"].value_counts()
# Out:
# Argentina         3
# Germany FR        3
# Netherlands       3
# Czechoslovakia    2
# Hungary           2
# Brazil            2
# Italy             2
# Sweden            1
# Germany           1
# France            1
# Name: Runners-Up, dtype: int64

# %%
import seaborn as sns
sns.set()
from matplotlib.pyplot import figure

# %%
fig = plt.figure()
figure(figsize=(8, 6), dpi=80).suptitle('World Cup: Attendance over Years', fontsize='x-large', fontweight='bold')
fig.subplots_adjust(top=0.87)
sns.barplot(x="Year", y="Attendance",
             data=groupped_attendance, palette = 'Dark2')
plt.xticks(rotation=45)
plt.legend(title='Attendance', labels=['Thousands of Fans'])
# plt.savefig("output.png", dpi=300)
plt.show()

# %%
fig = plt.figure()
figure(figsize=(8,6), dpi=80).suptitle("World Cup: Attendance over Years", fontsize="x-large", fontWeight="bold")
fig.subplots_adjust(top=0.87)
sns.subplot(x="")

# %% [markdown]
# ### Change type of Attendance column from object (str) to int

# %%
wc_data["Attendance"] = wc_data["Attendance"].str.replace('.','')
wc_data["Attendance"] = wc_data["Attendance"].astype(int)
wc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            20 non-null     int64
#  1   Country         20 non-null     object
#  2   Winner          20 non-null     object
#  3   Runners-Up      20 non-null     object
#  4   Third           20 non-null     object
#  5   Fourth          20 non-null     object
#  6   GoalsScored     20 non-null     int64
#  7   QualifiedTeams  20 non-null     int64
#  8   MatchesPlayed   20 non-null     int64
#  9   Attendance      20 non-null     int64
# dtypes: int64(5), object(5)
# memory usage: 1.7+ KB

# %% [markdown]
# ### Create plot of Attendance over years on World Cup

# %%
years_xticks = wc_data["Year"].astype(str)
# attendance = wc_data.groupby("Attendance")
wc_data.plot(kind="line", x="Year", y="Attendance", figsize=(12,6), colormap='gist_rainbow')
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# ### Find average of scored goals on every WC

# %%
goals_scored = wc_data.groupby("GoalsScored")
goals_scored.mean()
# Out:
#                Year  QualifiedTeams  MatchesPlayed  Attendance
# GoalsScored
# 70           1932.0            14.5           17.5    476774.5
# 84           1938.0            15.0           18.0    375700.0
# 88           1950.0            13.0           22.0   1045246.0
# 89           1964.0            16.0           32.0   1228153.5
# 95           1970.0            16.0           32.0   1603975.0
# 97           1974.0            16.0           38.0   1865753.0
# 102          1978.0            16.0           38.0   1545791.0
# 115          1990.0            24.0           52.0   2516215.0
# 126          1958.0            16.0           35.0    819810.0
# 132          1986.0            24.0           52.0   2394031.0
# 140          1954.0            16.0           26.0    768607.0
# 141          1994.0            24.0           52.0   3587538.0
# 145          2010.0            32.0           64.0   3178856.0
# 146          1982.0            24.0           52.0   2109723.0
# ...
